# %%
import matplotlib.pyplot as plt
from PIL import Image

img = "school.jpg"
image = Image.open(img)

plt.imshow(image)
plt.axis('off') 
plt.show()

# %%
print(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=716x299 at 0x2207D0285F0>

# %%
import numpy as np
img = Image.open("school.jpg")

# ছবিটিকে NumPy array এ রূপান্তর করুন
img_array = np.array(img)

# ছবির shape প্রিন্ট করুন
print("Image shape:", img_array.shape)
# Out:
# Image shape: (299, 716, 3)

# %% [markdown]
# ### OpenCV

# %%
import cv2
img_path = 'school.jpg' 
img = cv2.imread(img_path)
plt.imshow(img)

# %%
img_rgb= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ## PIL

# %%
from PIL import Image
img = Image.open('school.jpg')
plt.imshow(img)

# %%
image = cv2.imread('school.jpg')
blue, green, red = cv2.split(image)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,20))

plt.subplot(2,3,1)
plt.imshow(rgb)
plt.title("Normal")

plt.subplot(2,3,2)
plt.imshow(blue, cmap='gray')
plt.title("Blue")

plt.subplot(2,3,3)
plt.imshow(green, cmap='gray')
plt.title("Blue")

plt.subplot(2,3,4)
plt.imshow(red, cmap='gray')
plt.title("red")

plt.tight_layout()

# %% [markdown]
# ## ColorSpace conversion

# %%
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt


image = Image.open("school.jpg")


image_np = np.array(image)


gray_clr = cv2.cvtColor(image_np, cv2.COLOR_RGB2GRAY)  # RGB to Grayscale
hsv_clr = cv2.cvtColor(image_np, cv2.COLOR_RGB2HSV)   # RGB to HSV

plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.imshow(image_np)
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(gray_clr, cmap='gray')
plt.axis('off')
plt.title('Grayscale Image')

plt.subplot(1, 3, 3)
plt.imshow(hsv_clr)
plt.axis('off')
plt.title('HSV Image')

plt.show()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img = cv.imread('Orange.jpg', cv.IMREAD_GRAYSCALE)

# cv.threshold(gray_img, threshold_val, max_val, threshold_type)

# ret,thresh1 = cv.threshold(img, 190,255, cv.THRESH_BINARY)
ret,thresh1 = cv.threshold(img, 127,255, cv.THRESH_BINARY)
ret,thresh2 = cv.threshold(img, 127,255, cv.THRESH_BINARY_INV)
ret,thresh3 = cv.threshold(img, 127,255, cv.THRESH_TRUNC)
ret,thresh4 = cv.threshold(img, 127,255, cv.THRESH_TOZERO)
ret,thresh5 = cv.threshold(img, 127,255, cv.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'grey',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
